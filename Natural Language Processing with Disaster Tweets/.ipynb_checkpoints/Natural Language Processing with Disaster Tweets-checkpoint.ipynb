# %%
import numpy as np
import pandas as pd

# %%
train = pd.read_csv('dataset/train.csv')
test = pd.read_csv('dataset/test.csv')

# %%
train.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
test.head()
# Out:
#    id keyword location                                               text
# 0   0     NaN      NaN                 Just happened a terrible car crash
# 1   2     NaN      NaN  Heard about #earthquake is different cities, s...
# 2   3     NaN      NaN  there is a forest fire at spot pond, geese are...
# 3   9     NaN      NaN           Apocalypse lighting. #Spokane #wildfires
# 4  11     NaN      NaN      Typhoon Soudelor kills 28 in China and Taiwan

# %%
train.drop(columns=['id'],inplace=True)
test.drop(columns=['id'],inplace=True)

# %%
train.head()
# Out:
#   keyword location                                               text  target
# 0     NaN      NaN  Our Deeds are the Reason of this #earthquake M...       1
# 1     NaN      NaN             Forest fire near La Ronge Sask. Canada       1
# 2     NaN      NaN  All residents asked to 'shelter in place' are ...       1
# 3     NaN      NaN  13,000 people receive #wildfires evacuation or...       1
# 4     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...       1

# %%
test.head()
# Out:
#   keyword location                                               text
# 0     NaN      NaN                 Just happened a terrible car crash
# 1     NaN      NaN  Heard about #earthquake is different cities, s...
# 2     NaN      NaN  there is a forest fire at spot pond, geese are...
# 3     NaN      NaN           Apocalypse lighting. #Spokane #wildfires
# 4     NaN      NaN      Typhoon Soudelor kills 28 in China and Taiwan

# %%
train['keyword'].unique()
# Out:
# array([nan, 'ablaze', 'accident', 'aftershock', 'airplane%20accident',
#        'ambulance', 'annihilated', 'annihilation', 'apocalypse',
#        'armageddon', 'army', 'arson', 'arsonist', 'attack', 'attacked',
#        'avalanche', 'battle', 'bioterror', 'bioterrorism', 'blaze',
#        'blazing', 'bleeding', 'blew%20up', 'blight', 'blizzard', 'blood',
#        'bloody', 'blown%20up', 'body%20bag', 'body%20bagging',
#        'body%20bags', 'bomb', 'bombed', 'bombing', 'bridge%20collapse',
#        'buildings%20burning', 'buildings%20on%20fire', 'burned',
#        'burning', 'burning%20buildings', 'bush%20fires', 'casualties',
#        'casualty', 'catastrophe', 'catastrophic', 'chemical%20emergency',
#        'cliff%20fall', 'collapse', 'collapsed', 'collide', 'collided',
#        'collision', 'crash', 'crashed', 'crush', 'crushed', 'curfew',
#        'cyclone', 'damage', 'danger', 'dead', 'death', 'deaths', 'debris',
# ...

# %%
train['location'].unique()
# Out:
# array([nan, 'Birmingham', 'Est. September 2012 - Bristol', ...,
#        'Vancouver, Canada', 'London ', 'Lincoln'], dtype=object)

# %%
train.drop(columns=['location'],inplace=True)
test.drop(columns=['location'],inplace=True)

# %%
train.head()
# Out:
#   keyword                                               text  target
# 0     NaN  Our Deeds are the Reason of this #earthquake M...       1
# 1     NaN             Forest fire near La Ronge Sask. Canada       1
# 2     NaN  All residents asked to 'shelter in place' are ...       1
# 3     NaN  13,000 people receive #wildfires evacuation or...       1
# 4     NaN  Just got sent this photo from Ruby #Alaska as ...       1

# %%
test.head()
# Out:
#   keyword                                               text
# 0     NaN                 Just happened a terrible car crash
# 1     NaN  Heard about #earthquake is different cities, s...
# 2     NaN  there is a forest fire at spot pond, geese are...
# 3     NaN           Apocalypse lighting. #Spokane #wildfires
# 4     NaN      Typhoon Soudelor kills 28 in China and Taiwan

# %%
train.fillna("a",inplace=True)
test.fillna("a",inplace=True)

# %%
train.head()
# Out:
#   keyword                                               text  target
# 0       a  Our Deeds are the Reason of this #earthquake M...       1
# 1       a             Forest fire near La Ronge Sask. Canada       1
# 2       a  All residents asked to 'shelter in place' are ...       1
# 3       a  13,000 people receive #wildfires evacuation or...       1
# 4       a  Just got sent this photo from Ruby #Alaska as ...       1

# %%
train['keyword'].unique()
# Out:
# array(['a', 'ablaze', 'accident', 'aftershock', 'airplane%20accident',
#        'ambulance', 'annihilated', 'annihilation', 'apocalypse',
#        'armageddon', 'army', 'arson', 'arsonist', 'attack', 'attacked',
#        'avalanche', 'battle', 'bioterror', 'bioterrorism', 'blaze',
#        'blazing', 'bleeding', 'blew%20up', 'blight', 'blizzard', 'blood',
#        'bloody', 'blown%20up', 'body%20bag', 'body%20bagging',
#        'body%20bags', 'bomb', 'bombed', 'bombing', 'bridge%20collapse',
#        'buildings%20burning', 'buildings%20on%20fire', 'burned',
#        'burning', 'burning%20buildings', 'bush%20fires', 'casualties',
#        'casualty', 'catastrophe', 'catastrophic', 'chemical%20emergency',
#        'cliff%20fall', 'collapse', 'collapsed', 'collide', 'collided',
#        'collision', 'crash', 'crashed', 'crush', 'crushed', 'curfew',
#        'cyclone', 'damage', 'danger', 'dead', 'death', 'deaths', 'debris',
# ...

# %%
train['review'] = train['keyword'] + ' '+ train['text']

# %%
test['review'] = test['keyword'] + ' '+test['text']

# %%
train.head()
# Out:
#   keyword                                               text  target  \
# 0       a  Our Deeds are the Reason of this #earthquake M...       1
# 1       a             Forest fire near La Ronge Sask. Canada       1
# 2       a  All residents asked to 'shelter in place' are ...       1
# 3       a  13,000 people receive #wildfires evacuation or...       1
# 4       a  Just got sent this photo from Ruby #Alaska as ...       1
#
#                                               review
# 0  a Our Deeds are the Reason of this #earthquake...
# 1           a Forest fire near La Ronge Sask. Canada
# 2  a All residents asked to 'shelter in place' ar...
# 3  a 13,000 people receive #wildfires evacuation ...
# 4  a Just got sent this photo from Ruby #Alaska a...

# %%
test.head()
# Out:
#   keyword                                               text  \
# 0       a                 Just happened a terrible car crash
# 1       a  Heard about #earthquake is different cities, s...
# 2       a  there is a forest fire at spot pond, geese are...
# 3       a           Apocalypse lighting. #Spokane #wildfires
# 4       a      Typhoon Soudelor kills 28 in China and Taiwan
#
#                                               review
# 0               a Just happened a terrible car crash
# 1  a Heard about #earthquake is different cities,...
# 2  a there is a forest fire at spot pond, geese a...
# 3         a Apocalypse lighting. #Spokane #wildfires
# 4    a Typhoon Soudelor kills 28 in China and Taiwan

# %%
train.drop(columns=['keyword','text'],inplace=True)
test.drop(columns=['keyword','text'],inplace=True)

# %%
train.head()
# Out:
#    target                                             review
# 0       1  a Our Deeds are the Reason of this #earthquake...
# 1       1           a Forest fire near La Ronge Sask. Canada
# 2       1  a All residents asked to 'shelter in place' ar...
# 3       1  a 13,000 people receive #wildfires evacuation ...
# 4       1  a Just got sent this photo from Ruby #Alaska a...

# %%
test.head()
# Out:
#                                               review
# 0               a Just happened a terrible car crash
# 1  a Heard about #earthquake is different cities,...
# 2  a there is a forest fire at spot pond, geese a...
# 3         a Apocalypse lighting. #Spokane #wildfires
# 4    a Typhoon Soudelor kills 28 in China and Taiwan

# %%
## Pre-Processing

# %%
text = train['review']

# %%
text.shape
# Out:
# (7613,)

# %%
text2 = test['review']

# %%
text2.shape
# Out:
# (3263,)

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
stop_words = stopwords.words('english')
stop_words
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
import re
from nltk.stem import WordNetLemmatizer

# %%
lemma  = WordNetLemmatizer()

# %%
corpus = []
for i in range(len(text)):
    temp = re.sub('[^a-zA-Z]',' ',text[i])
    temp = temp.lower()
    temp = temp.split()
    temp = [lemma.lemmatize(p) for p in temp if p not in set(stopwords.words('english'))]
    temp = ' '.join(temp)
    corpus.append(temp)

# %%
corpus
# Out:
# ['deed reason earthquake may allah forgive u',
#  'forest fire near la ronge sask canada',
#  'resident asked shelter place notified officer evacuation shelter place order expected',
#  'people receive wildfire evacuation order california',
#  'got sent photo ruby alaska smoke wildfire pours school',
#  'rockyfire update california hwy closed direction due lake county fire cafire wildfire',
#  'flood disaster heavy rain cause flash flooding street manitou colorado spring area',
#  'top hill see fire wood',
#  'emergency evacuation happening building across street',
#  'afraid tornado coming area',
#  'three people died heat wave far',
#  'haha south tampa getting flooded hah wait second live south tampa gonna gonna fvck flooding',
#  'raining flooding florida tampabay tampa day lost count',
#  'flood bago myanmar arrived bago',
#  'damage school bus multi car crash breaking',
#  'man',
#  'love fruit',
#  'summer lovely',
#  'car fast',
#  'goooooooaaaaaal',
#  'ridiculous',
# ...

# %%
for i in range(len(train)):
    train.loc[i,'review'] = corpus[i]

# %%
train.head(4)
# Out:
#    target                                             review
# 0       1         deed reason earthquake may allah forgive u
# 1       1              forest fire near la ronge sask canada
# 2       1  resident asked shelter place notified officer ...
# 3       1  people receive wildfire evacuation order calif...

# %%
corpus = []
for i in range(len(text2)):
    temp = re.sub('[^a-zA-Z]',' ',text2[i])
    temp = temp.lower()
    temp = temp.split()
    temp = [lemma.lemmatize(p) for p in temp if p not in set(stopwords.words('english'))]
    temp = ' '.join(temp)
    corpus.append(temp)

# %%
for i in range(len(test)):
    test.loc[i,'review'] = corpus[i]

# %%
test.head(4)
# Out:
#                                               review
# 0                        happened terrible car crash
# 1  heard earthquake different city stay safe ever...
# 2  forest fire spot pond goose fleeing across str...
# 3               apocalypse lighting spokane wildfire

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(train['review'] , train['target'] , 
                                                       test_size=0.3 ,random_state=101)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from xgboost import XGBClassifier

# %% [markdown]
# ## Random Forest Classifier

# %%
rf = Pipeline([
                       ('TF-IDF', TfidfVectorizer()),
                       ('Classifier',RandomForestClassifier())
                      ])

# %%
rf.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('TF-IDF', TfidfVectorizer()),
#                 ('Classifier', RandomForestClassifier())])

# %%
# Predict the model by using train and test data

y_pred_train = rf.predict(x_train)
y_pred_test = rf.predict(x_test)

# %%
print(classification_report(y_train,y_pred_train))
print("***********"*10)
print(classification_report(y_test,y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3012
#            1       1.00      1.00      1.00      2317
#
#     accuracy                           1.00      5329
#    macro avg       1.00      1.00      1.00      5329
# weighted avg       1.00      1.00      1.00      5329
#
# **************************************************************************************************************
#               precision    recall  f1-score   support
#
#            0       0.77      0.91      0.83      1330
#            1       0.83      0.61      0.71       954
#
#     accuracy                           0.79      2284
#    macro avg       0.80      0.76      0.77      2284
# weighted avg       0.79      0.79      0.78      2284

# %%
print(accuracy_score(y_train,y_pred_train))
print("***********"*10)
print(accuracy_score(y_test,y_pred_test))
# Out:
# 0.9975605179208107
# **************************************************************************************************************
# 0.787215411558669

# %%
y_pred_test_submission = rf.predict(test['review'])

# %%
submission = pd.read_csv('dataset/sample_submission.csv')

# %%
for i in range(len(submission)):
    submission.loc[i , 'target'] = y_pred_test_submission[i]

# %%
submission.to_csv('submission.csv', index=False)  # 'index=False' prevents saving the index column

# %% [markdown]
# ## svm

# %%
svm = Pipeline([
                       ('TF-IDF', TfidfVectorizer()),
                       ('Classifier',SVC())
                      ])

# %%
svm.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('TF-IDF', TfidfVectorizer()), ('Classifier', SVC())])

# %%
# Predict the model by using train and test data

y_pred_train = svm.predict(x_train)
y_pred_test = svm.predict(x_test)

# %%
print(classification_report(y_train,y_pred_train))
print("***********"*10)
print(classification_report(y_test,y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      3012
#            1       0.99      0.94      0.96      2317
#
#     accuracy                           0.97      5329
#    macro avg       0.97      0.96      0.97      5329
# weighted avg       0.97      0.97      0.97      5329
#
# **************************************************************************************************************
#               precision    recall  f1-score   support
#
#            0       0.79      0.87      0.83      1330
#            1       0.80      0.69      0.74       954
#
#     accuracy                           0.80      2284
#    macro avg       0.80      0.78      0.78      2284
# weighted avg       0.80      0.80      0.79      2284

# %%
print(accuracy_score(y_train,y_pred_train))
print("***********"*10)
print(accuracy_score(y_test,y_pred_test))
# Out:
# 0.9675361231000188
# **************************************************************************************************************
# 0.7955341506129597

# %%
y_pred_test_submission = svm.predict(test['review'])

# %%
submission = pd.read_csv('dataset/sample_submission.csv')

# %%
for i in range(len(submission)):
    submission.loc[i , 'target'] = y_pred_test_submission[i]

# %%
submission.to_csv('submission.csv', index=False)  # 'index=False' prevents saving the index column

# %% [markdown]
# ## XGBOOST

# %%
xgb_classifier = Pipeline([
    ('TF-IDF', TfidfVectorizer()),
                       ('Classifier',XGBClassifier())
                      ])

# %%
xgb_classifier.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('TF-IDF', TfidfVectorizer()),
#                 ('Classifier',
#                  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                colsample_bylevel=None, colsample_bynode=None,
#                                colsample_bytree=None, device=None,
#                                early_stopping_rounds=None,
#                                enable_categorical=False, eval_metric=None,
#                                feature_types=None, gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=None,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=None, max_leaves=None,
#                                min_child_weight=None, missing=nan,
# ...

# %%
y_pred_train = xgb_classifier.predict(x_train)
y_pred_test = xgb_classifier.predict(x_test)

# %%
print(classification_report(y_train,y_pred_train))
print("***********"*10)
print(classification_report(y_test,y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.97      0.90      3012
#            1       0.95      0.75      0.84      2317
#
#     accuracy                           0.88      5329
#    macro avg       0.90      0.86      0.87      5329
# weighted avg       0.89      0.88      0.87      5329
#
# **************************************************************************************************************
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83      1330
#            1       0.81      0.62      0.71       954
#
#     accuracy                           0.78      2284
#    macro avg       0.79      0.76      0.77      2284
# weighted avg       0.79      0.78      0.78      2284

# %%
print(accuracy_score(y_train,y_pred_train))
print("***********"*10)
print(accuracy_score(y_test,y_pred_test))
# Out:
# 0.8774629386376431
# **************************************************************************************************************
# 0.7832749562171629

# %%
y_pred_test_submission = xgb_classifier.predict(test['review'])

# %%
submission = pd.read_csv('dataset/sample_submission.csv')

# %%
for i in range(len(submission)):
    submission.loc[i , 'target'] = y_pred_test_submission[i]

# %%
submission.to_csv('submission.csv', index=False)  # 'index=False' prevents saving the index column

# %%
## TRY BERT MODEL HERE
